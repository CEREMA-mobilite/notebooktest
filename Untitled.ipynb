# %%
x=5
y=6
print x*y
# Out:
# 30

# %% [markdown]
# voici du texte
# d'explications

# %%
# sous-titre
from gtfslib.dao import Dao
dao = Dao("test.sqlite")
for stop in dao.stops():
    print(stop.stop_name)

# %%
print dao

# %%
for stop in dao.stops():
    print("test")

# %%
# !cd d:/tests

# %%
# !cd /d d:/tests/gtfslib

# %%
# %run d:/tests/gtfslib/gtfsplugins/gtfsrun.py d:/TESTS/gtfslib/test.sqlite TripsPerDay
# Out:
# Loading calendar dates...
# Loaded 694 dates
# Processing trips...
# 0 trips...
# Processed 534 trips
# +------------+-----+
# |       date | SUM |
# +------------+-----+
# | 2012-10-15 | 164 |
# | 2012-10-16 | 164 |
# | 2012-10-17 | 164 |
# | 2012-10-18 | 164 |
# | 2012-10-19 | 164 |
# | 2012-10-20 | 164 |
# | 2012-10-22 | 164 |
# | 2012-10-23 | 164 |
# | 2012-10-24 | 164 |
# | 2012-10-25 | 164 |
# | 2012-10-26 | 164 |
# | 2012-10-27 | 164 |
# | 2012-10-29 | 164 |
# | 2012-10-30 | 164 |
# | 2012-10-31 | 164 |
# | 2012-11-01 | 164 |
# | 2012-11-02 | 164 |
# | 2012-11-03 | 164 |
# | 2012-11-05 | 164 |
# | 2012-11-06 | 164 |
# | 2012-11-07 | 164 |
# | 2012-11-08 | 164 |
# | 2012-11-09 | 164 |
# | 2012-11-10 | 164 |
# | 2012-11-12 | 164 |
# | 2012-11-13 | 164 |
# | 2012-11-14 | 164 |
# | 2012-11-15 | 164 |
# | 2012-11-16 | 164 |
# | 2012-11-17 | 164 |
# | 2012-11-19 | 164 |
# | 2012-11-20 | 164 |
# | 2012-11-21 | 164 |
# | 2012-11-22 | 164 |
# | 2012-11-23 | 164 |
# ...
